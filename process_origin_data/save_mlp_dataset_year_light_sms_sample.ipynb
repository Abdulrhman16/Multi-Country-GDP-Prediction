# %%
import os
import pandas as pd
import numpy as np

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3,4"

# %% [markdown]
# # MLP Year Dataset with Light Intensity Data
#
# Generate and save MLP datasets with light intensity data for yearly GDP predictions (2013-2019)

# %%
import torch
import random


def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


set_seed(1)

# %% [markdown]
# ## 1. Setup and Imports

# %%
df_weo = pd.read_excel("yearly/integrated_yearly_data.xlsx", index_col=0)
df_weo.index = [x for x in range(len(df_weo))]

# %% [markdown]
# ## 2. Load and Process Main Economic Data

# %%
df_weo = df_weo[
    [
        "Country Name",
        "Country Code",
        "year",
        "Rural population growth (annual %)",
        "General government final consumption expenditure (annual % growth)",
        "Consumer price index (2010 = 100)",
        "Exports of goods and services (annual % growth)_x",
        "Urban population growth (annual %)",
        "GDP growth (annual %)",
        "Population growth (annual %)",
        "Inflation, GDP deflator (annual %)",
        "Imports of goods and services (annual % growth)",
        "Final consumption expenditure (annual % growth)",
        "Unemployment, total (% of total labor force) (national estimate)",
        "Inflation, consumer prices (annual %)",
        "Gross fixed capital formation (annual % growth)",
        "Households and NPISHs Final consumption expenditure (annual % growth)",
    ]
]

# %%
df_weo = df_weo.dropna(subset=["GDP growth (annual %)"])
df_weo.index = [x for x in range(len(df_weo))]

# %%
df_weo["year"].unique()
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
df_weo = df_weo.loc[(df_weo["year"] >= 2013) & (df_weo["year"] <= 2019)]

# %%
df_merge = df_weo.dropna()
df_merge
# Out:
#            Country Name Country Code  year  \
# 540           Australia          AUS  2013
# 541              Brazil          BRA  2013
# 542              Canada          CAN  2013
# 543         Switzerland          CHE  2013
# 544             Germany          DEU  2013
# ..                  ...          ...   ...
# 670              Poland          POL  2019
# 671  Russian Federation          RUS  2019
# 672        Saudi Arabia          SAU  2019
# 673             Turkiye          TUR  2019
# 674       United States          USA  2019
#
#      Rural population growth (annual %)  \
# 540                            1.033771
# 541                           -1.046804
# 542                            0.838999
# 543                            1.070130
# 544                            0.229090
# ..                                  ...
# 670                            0.028134
# 671                           -0.653729
# 672                            0.907224
# 673                           -0.548956
# 674                           -0.695262
#
#      General government final consumption expenditure (annual % growth)  \
# 540                                           0.571659
# 541                                           1.510121
# 542                                          -0.789646
# 543                                           1.799332
# 544                                           1.411439
# ..                                                 ...
# 670                                           6.482303
# 671                                           2.369754
# 672                                          -2.971078
# 673                                           3.907612
# 674                                           3.947474
#
#      Consumer price index (2010 = 100)  \
# 540                         107.700312
# 541                         119.372104
# 542                         105.452204
# 543                          99.320878
# 544                         105.692140
# ..                                 ...
# 670                         114.111779
# 671                         180.750264
# 672                         118.399825
# 673                         234.437126
# 674                         117.244195
#
#      Exports of goods and services (annual % growth)_x  \
# 540                                           5.305435
# 541                                           1.830295
# 542                                           2.453414
# 543                                          14.171961
# 544                                           1.004464
# ..                                                 ...
# 670                                           5.337289
# 671                                           0.732545
# 672                                          -4.996865
# 673                                           5.278520
# 674                                           0.511353
#
#      Urban population growth (annual %)  GDP growth (annual %)  \
# 540                            1.838176               2.606198
# 541                            1.204556               3.004823
# 542                            1.107110               2.325814
# 543                            1.178392               1.792144
# 544                            0.285857               0.437591
# ..                                  ...                    ...
# 670                           -0.059399               4.449988
# 671                            0.157115               2.198076
# 672                            2.547829               0.832280
# 673                            2.075703               0.818526
# 674                            0.701868               2.294439
#
#      Population growth (annual %)  Inflation, GDP deflator (annual %)  \
# 540                      1.721151                           -0.163782
# 541                      0.868346                            7.504565
# 542                      1.056591                            1.740738
# 543                      1.149880                           -0.086843
# 544                      0.272900                            1.959392
# ..                            ...                                 ...
# 670                     -0.024427                            3.032537
# 671                     -0.049569                            3.263133
# 672                      2.284589                           -1.764821
# 673                      1.429697                           13.867735
# 674                      0.455381                            1.793931
#
#      Imports of goods and services (annual % growth)  \
# 540                                         0.697428
# 541                                         6.669679
# 542                                         2.081262
# 543                                        12.268706
# 544                                         2.675547
# ..                                               ...
# 670                                         3.192354
# 671                                         3.130358
# 672                                         9.580893
# 673                                        -5.011971
# 674                                         1.197294
#
#      Final consumption expenditure (annual % growth)  \
# 540                                         1.564854
# 541                                         3.019444
# 542                                         1.686292
# 543                                         2.178382
# 544                                         0.635020
# ..                                               ...
# 670                                         4.114586
# 671                                         3.389621
# 672                                         2.968098
# 673                                         1.965464
# 674                                         2.333026
#
#      Unemployment, total (% of total labor force) (national estimate)  \
# 540                                              5.663
# 541                                              7.071
# 542                                              7.143
# 543                                              4.747
# 544                                              5.231
# ..                                                 ...
# 670                                              3.277
# 671                                              4.496
# 672                                              5.636
# 673                                             13.730
# 674                                              3.669
#
#      Inflation, consumer prices (annual %)  \
# 540                               2.449889
# 541                               6.204311
# 542                               0.938292
# 543                              -0.217323
# 544                               1.504723
# ..                                     ...
# 670                               2.227479
# 671                               4.470367
# 672                              -2.093333
# 673                              15.176822
# 674                               1.812210
#
#      Gross fixed capital formation (annual % growth)  \
# 540                                         2.891657
# 541                                         5.827201
# 542                                         1.448880
# 543                                         1.118239
# 544                                        -1.296008
# ..                                               ...
# 670                                         6.242051
# 671                                         0.966743
# 672                                         4.827888
# 673                                       -12.471792
# 674                                         2.880129
#
#      Households and NPISHs Final consumption expenditure (annual % growth)
# 540                                           1.915095
# 541                                           3.474859
# 542                                           2.627830
# 543                                           2.259422
# 544                                           0.361832
# ..                                                 ...
# 670                                           3.404616
# 671                                           3.753272
# 672                                           6.488206
# 673                                           1.504079
# 674                                           2.001761
#
# [135 rows x 17 columns]

# %% [markdown]
# ## 3. Load and Process Light Intensity Data

# %%
df_code = pd.read_excel("./light_data/IMF_ISO.xlsx", header=None)
df_code.columns = ["REF_AREA", "ADM0_ISO"]
# df_code

# %%
df_light_data = pd.read_csv("./light_data/light_data.csv", index_col=0)
df_light_data = df_light_data.merge(df_code, how="left", on="ADM0_ISO")
df_light_data = df_light_data.dropna(subset=["REF_AREA"])
df_light_data["REF_AREA"] = df_light_data["REF_AREA"].astype(int)
# df_light_data

# %%
df_light_data = df_light_data.loc[
    (df_light_data["year_month"] >= 201301) & (df_light_data["year_month"] <= 202412)
]

# %%
# drop some country nan value
df_light_data = pd.DataFrame(
    df_light_data.groupby(["ADM0_ISO", "year_month", "REF_AREA"])
    .max("sum")
    .reset_index()
)

# %%
# 将字符串转换为日期时间格式
df_light_data["year_month"] = pd.to_datetime(df_light_data["year_month"], format="%Y%m")

# 提取季度信息
df_light_data["year"] = df_light_data["year_month"].dt.year
df_light_data["month"] = df_light_data["year_month"].dt.month

# %%
df_light_data
# Out:
#       ADM0_ISO year_month  REF_AREA            sum      mean       std  year  \
# 0          ABW 2013-01-01       314    3236.639999  4.035711  6.253305  2013
# 1          ABW 2013-02-01       314    3422.669997  4.235978  5.449601  2013
# 2          ABW 2013-03-01       314    3059.299997  3.786262  4.239345  2013
# 3          ABW 2013-04-01       314    3186.650002  3.943874  4.771718  2013
# 4          ABW 2013-05-01       314    3253.700000  4.026856  5.988211  2013
# ...        ...        ...       ...            ...       ...       ...   ...
# 25398      ZWE 2023-09-01       698  781236.070851  0.255524  1.733717  2023
# 25399      ZWE 2023-10-01       698  934729.121041  0.305728  2.026455  2023
# 25400      ZWE 2023-11-01       698  958243.855843  0.313420  0.937193  2023
# 25401      ZWE 2023-12-01       698  661726.530320  0.216734  1.098943  2023
# 25402      ZWE 2024-01-01       698  492457.070369  0.161225  0.443856  2024
#
#        month
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 25398      9
# 25399     10
# 25400     11
# 25401     12
# 25402      1
#
# [25403 rows x 8 columns]

# %%
# average of year
df_light_data = (
    df_light_data.groupby(["ADM0_ISO", "REF_AREA", "year"]).mean().reset_index()
)
df_light_data
# Out:
#      ADM0_ISO  REF_AREA  year          year_month            sum      mean  \
# 0         ABW       314  2013 2013-06-16 12:00:00    3285.883333  4.069567
# 1         ABW       314  2014 2014-06-16 12:00:00    3542.806667  4.398952
# 2         ABW       314  2015 2015-06-16 12:00:00    3616.676666  4.478046
# 3         ABW       314  2016 2016-06-16 08:00:00    3965.599998  4.916097
# 4         ABW       314  2017 2017-06-16 12:00:00    5051.679166  6.252078
# ...       ...       ...   ...                 ...            ...       ...
# 2287      ZWE       698  2020 2020-06-16 08:00:00  483571.902194  0.251580
# 2288      ZWE       698  2021 2021-06-16 12:00:00  547103.053408  0.178995
# 2289      ZWE       698  2022 2022-06-16 12:00:00  571825.590048  0.187945
# 2290      ZWE       698  2023 2023-06-16 12:00:00  666154.859491  0.217988
# 2291      ZWE       698  2024 2024-01-01 00:00:00  492457.070369  0.161225
#
#            std  month
# 0     5.464744    6.5
# 1     5.539452    6.5
# 2     5.527158    6.5
# 3     6.062411    6.5
# 4     7.150565    6.5
# ...        ...    ...
# 2287  0.564372    6.5
# 2288  0.626771    6.5
# 2289  0.663419    6.5
# 2290  1.065642    6.5
# 2291  0.443856    1.0
#
# [2292 rows x 8 columns]

# %%
df_merge["country"] = df_merge["Country Code"]

# %% [markdown]
# ## 4. Merge Economic and Light Data

# %%
dict_country_code = {}
for i in range(len(df_merge["country"].unique())):
    dict_country_code[df_merge["country"].unique()[i]] = [
        "CHN",
        "USA",
        "DEU",
        "JPN",
        "IND",
        "GBR",
        "FRA",
        "BRA",
        "ITA",
        "CAN",
        "RUS",
        "MEX",
        "AUS",
        "KOR",
        "ESP",
        "IDN",
        "NLD",
        "TUR",
        "SAU",
        "CHE",
        "POL",
    ][i]
dict_country_code = dict((v, k) for k, v in dict_country_code.items())
df_light_data_select = df_light_data.loc[
    df_light_data["ADM0_ISO"].isin(dict_country_code.keys())
][["ADM0_ISO", "year", "sum", "mean", "std"]]

df_light_data_select["country"] = df_light_data_select["ADM0_ISO"].apply(
    lambda x: dict_country_code[x]
)
df_light_data_select
# Out:
#      ADM0_ISO  year           sum      mean       std country
# 108       AUS  2013  4.025313e+06  0.156927  6.314056     MEX
# 109       AUS  2014  3.797938e+06  0.409307  7.559085     MEX
# 110       AUS  2015  4.048216e+06  0.521269  9.966388     MEX
# 111       AUS  2016  2.577938e+06  0.329611  6.365509     MEX
# 112       AUS  2017  8.987109e+06  0.248867  4.003674     MEX
# ...       ...   ...           ...       ...       ...     ...
# 2167      USA  2020  5.768624e+07  0.897867  6.613326     BRA
# 2168      USA  2021  6.156864e+07  0.056712  1.596962     BRA
# 2169      USA  2022  7.049229e+07  0.064932  1.750268     BRA
# 2170      USA  2023  6.794478e+07  0.062586  1.681313     BRA
# 2171      USA  2024  1.073009e+08  0.098837  2.749738     BRA
#
# [240 rows x 6 columns]

# %%
df_merge = pd.merge(df_merge, df_light_data_select, how="left", on=["country", "year"])

# %%
df_merge
# Out:
#            Country Name Country Code  year  \
# 0             Australia          AUS  2013
# 1                Brazil          BRA  2013
# 2                Canada          CAN  2013
# 3           Switzerland          CHE  2013
# 4               Germany          DEU  2013
# ..                  ...          ...   ...
# 130              Poland          POL  2019
# 131  Russian Federation          RUS  2019
# 132        Saudi Arabia          SAU  2019
# 133             Turkiye          TUR  2019
# 134       United States          USA  2019
#
#      Rural population growth (annual %)  \
# 0                              1.033771
# 1                             -1.046804
# 2                              0.838999
# 3                              1.070130
# 4                              0.229090
# ..                                  ...
# 130                            0.028134
# 131                           -0.653729
# 132                            0.907224
# 133                           -0.548956
# 134                           -0.695262
#
#      General government final consumption expenditure (annual % growth)  \
# 0                                             0.571659
# 1                                             1.510121
# 2                                            -0.789646
# 3                                             1.799332
# 4                                             1.411439
# ..                                                 ...
# 130                                           6.482303
# 131                                           2.369754
# 132                                          -2.971078
# 133                                           3.907612
# 134                                           3.947474
#
#      Consumer price index (2010 = 100)  \
# 0                           107.700312
# 1                           119.372104
# 2                           105.452204
# 3                            99.320878
# 4                           105.692140
# ..                                 ...
# 130                         114.111779
# 131                         180.750264
# 132                         118.399825
# 133                         234.437126
# 134                         117.244195
#
#      Exports of goods and services (annual % growth)_x  \
# 0                                             5.305435
# 1                                             1.830295
# 2                                             2.453414
# 3                                            14.171961
# 4                                             1.004464
# ..                                                 ...
# 130                                           5.337289
# 131                                           0.732545
# 132                                          -4.996865
# 133                                           5.278520
# 134                                           0.511353
#
#      Urban population growth (annual %)  GDP growth (annual %)  \
# 0                              1.838176               2.606198
# 1                              1.204556               3.004823
# 2                              1.107110               2.325814
# 3                              1.178392               1.792144
# 4                              0.285857               0.437591
# ..                                  ...                    ...
# 130                           -0.059399               4.449988
# 131                            0.157115               2.198076
# 132                            2.547829               0.832280
# 133                            2.075703               0.818526
# 134                            0.701868               2.294439
#
#      Population growth (annual %)  ...  \
# 0                        1.721151  ...
# 1                        0.868346  ...
# 2                        1.056591  ...
# 3                        1.149880  ...
# 4                        0.272900  ...
# ..                            ...  ...
# 130                     -0.024427  ...
# 131                     -0.049569  ...
# 132                      2.284589  ...
# 133                      1.429697  ...
# 134                      0.455381  ...
#
#      Final consumption expenditure (annual % growth)  \
# 0                                           1.564854
# 1                                           3.019444
# 2                                           1.686292
# 3                                           2.178382
# 4                                           0.635020
# ..                                               ...
# 130                                         4.114586
# 131                                         3.389621
# 132                                         2.968098
# 133                                         1.965464
# 134                                         2.333026
#
#      Unemployment, total (% of total labor force) (national estimate)  \
# 0                                                5.663
# 1                                                7.071
# 2                                                7.143
# 3                                                4.747
# 4                                                5.231
# ..                                                 ...
# 130                                              3.277
# 131                                              4.496
# 132                                              5.636
# 133                                             13.730
# 134                                              3.669
#
#      Inflation, consumer prices (annual %)  \
# 0                                 2.449889
# 1                                 6.204311
# 2                                 0.938292
# 3                                -0.217323
# 4                                 1.504723
# ..                                     ...
# 130                               2.227479
# 131                               4.470367
# 132                              -2.093333
# 133                              15.176822
# 134                               1.812210
#
#      Gross fixed capital formation (annual % growth)  \
# 0                                           2.891657
# 1                                           5.827201
# 2                                           1.448880
# 3                                           1.118239
# 4                                          -1.296008
# ..                                               ...
# 130                                         6.242051
# 131                                         0.966743
# 132                                         4.827888
# 133                                       -12.471792
# 134                                         2.880129
#
#      Households and NPISHs Final consumption expenditure (annual % growth)  \
# 0                                             1.915095
# 1                                             3.474859
# 2                                             2.627830
# 3                                             2.259422
# 4                                             0.361832
# ..                                                 ...
# 130                                           3.404616
# 131                                           3.753272
# 132                                           6.488206
# 133                                           1.504079
# 134                                           2.001761
#
#      country  ADM0_ISO           sum      mean        std
# 0        AUS       CHN  2.173635e+07  0.408269   3.095361
# 1        BRA       USA  5.387293e+07  0.847616   5.971115
# 2        CAN       DEU  2.048263e+06  0.777476   2.729972
# 3        CHE       JPN  2.989069e+06  1.366240   5.156093
# 4        DEU       IND  9.329172e+06  0.604302   3.175042
# ..       ...       ...           ...       ...        ...
# 130      POL       ESP  4.078532e+06  1.319188   6.476156
# 131      RUS       IDN  3.502264e+06  0.412781   3.096644
# 132      SAU       NLD  1.214743e+06  4.296103  50.873116
# 133      TUR       TUR  5.668421e+06  1.212351   5.090605
# 134      USA       SAU  1.127146e+07  1.145222  10.353539
#
# [135 rows x 22 columns]

# %%
df_filter = df_merge.dropna()

# %%
country_list = df_filter["Country Name"].unique()
code_map = {}
for i in range(len(country_list)):
    code_map[country_list[i]] = i

df_filter["country_code"] = df_filter["Country Name"].apply(lambda x: code_map[x])

# %%
## 5a. Create Country Code Mapping (before feature extraction)

# %%
data_v = [
    "Rural population growth (annual %)",
    "General government final consumption expenditure (annual % growth)",
    "Consumer price index (2010 = 100)",
    "Exports of goods and services (annual % growth)_x",
    "Urban population growth (annual %)",
    "Population growth (annual %)",
    "Inflation, GDP deflator (annual %)",
    "Imports of goods and services (annual % growth)",
    "Final consumption expenditure (annual % growth)",
    "Unemployment, total (% of total labor force) (national estimate)",
    "Inflation, consumer prices (annual %)",
    "Gross fixed capital formation (annual % growth)",
    "Households and NPISHs Final consumption expenditure (annual % growth)",
    "sum",
    "mean",
    "std",
    "country_code",
    "year",
]
df_filter.columns
# Out:
# Index(['Country Name', 'Country Code', 'year',
#        'Rural population growth (annual %)',
#        'General government final consumption expenditure (annual % growth)',
#        'Consumer price index (2010 = 100)',
#        'Exports of goods and services (annual % growth)_x',
#        'Urban population growth (annual %)', 'GDP growth (annual %)',
#        'Population growth (annual %)', 'Inflation, GDP deflator (annual %)',
#        'Imports of goods and services (annual % growth)',
#        'Final consumption expenditure (annual % growth)',
#        'Unemployment, total (% of total labor force) (national estimate)',
#        'Inflation, consumer prices (annual %)',
#        'Gross fixed capital formation (annual % growth)',
#        'Households and NPISHs Final consumption expenditure (annual % growth)',
#        'country', 'ADM0_ISO', 'sum', 'mean', 'std', 'country_code'],
#       dtype='object')

# %% [markdown]
# ## 5. Normalize Features

# %%
data = df_filter[data_v]

# %%
data.shape
# Out:
# (135, 18)

# %%
data.values
# Out:
# array([[ 1.03377143e+00,  5.71659356e-01,  1.07700312e+02, ...,
#          3.09536085e+00,  0.00000000e+00,  2.01300000e+03],
#        [-1.04680436e+00,  1.51012128e+00,  1.19372104e+02, ...,
#          5.97111487e+00,  1.00000000e+00,  2.01300000e+03],
#        [ 8.38999351e-01, -7.89645935e-01,  1.05452204e+02, ...,
#          2.72997177e+00,  2.00000000e+00,  2.01300000e+03],
#        ...,
#        [ 9.07224023e-01, -2.97107822e+00,  1.18399825e+02, ...,
#          5.08731163e+01,  1.60000000e+01,  2.01900000e+03],
#        [-5.48955802e-01,  3.90761204e+00,  2.34437126e+02, ...,
#          5.09060550e+00,  1.70000000e+01,  2.01900000e+03],
#        [-6.95262033e-01,  3.94747357e+00,  1.17244195e+02, ...,
#          1.03535389e+01,  1.80000000e+01,  2.01900000e+03]],
#       shape=(135, 18))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(data)
data = scaler.transform(data.values)
# Out:
# c:\Users\Administrator\Desktop\Github\Multi-Country-GDP-Prediction\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df_filter[data_v] = data

# %%
df_filter.head()
# Out:
#   Country Name Country Code      year  Rural population growth (annual %)  \
# 0    Australia          AUS -1.511794                            1.186917
# 1       Brazil          BRA -1.511794                           -0.549959
# 2       Canada          CAN -1.511794                            1.024320
# 3  Switzerland          CHE -1.511794                            1.217270
# 4      Germany          DEU -1.511794                            0.515165
#
#    General government final consumption expenditure (annual % growth)  \
# 0                                          -0.429109
# 1                                          -0.119310
# 2                                          -0.878494
# 3                                          -0.023838
# 4                                          -0.151886
#
#    Consumer price index (2010 = 100)  \
# 0                          -0.552582
# 1                          -0.022262
# 2                          -0.654727
# 3                          -0.933309
# 4                          -0.643825
#
#    Exports of goods and services (annual % growth)_x  \
# 0                                           0.587540
# 1                                          -0.500136
# 2                                          -0.305107
# 3                                           3.362653
# 4                                          -0.758610
#
#    Urban population growth (annual %)  GDP growth (annual %)  \
# 0                            1.085996               2.606198
# 1                            0.260984               3.004823
# 2                            0.134103               2.325814
# 3                            0.226917               1.792144
# 4                           -0.935218               0.437591
#
#    Population growth (annual %)  ...  \
# 0                      1.635038  ...
# 1                      0.255734  ...
# 2                      0.560196  ...
# 3                      0.711079  ...
# 4                     -0.707325  ...
#
#    Unemployment, total (% of total labor force) (national estimate)  \
# 0                                          -0.299153
# 1                                           0.040935
# 2                                           0.058325
# 3                                          -0.520402
# 4                                          -0.403498
#
#    Inflation, consumer prices (annual %)  \
# 0                              -0.022781
# 1                               1.204075
# 2                              -0.516735
# 3                              -0.894363
# 4                              -0.331639
#
#    Gross fixed capital formation (annual % growth)  \
# 0                                         0.138831
# 1                                         0.702851
# 2                                        -0.138377
# 3                                        -0.201905
# 4                                        -0.665766
#
#    Households and NPISHs Final consumption expenditure (annual % growth)  \
# 0                                          -0.138371
# 1                                           0.562389
# 2                                           0.181842
# 3                                           0.016326
# 4                                          -0.836209
#
#    country  ADM0_ISO       sum      mean       std  country_code
# 0      AUS       CHN  0.501962 -0.727731 -0.477515     -1.642656
# 1      BRA       USA  2.354106 -0.296918 -0.236511     -1.463095
# 2      CAN       DEU -0.632732 -0.365696 -0.508137     -1.283533
# 3      CHE       JPN -0.578510  0.211631 -0.304815     -1.103971
# 4      DEU       IND -0.213108 -0.535505 -0.470838     -0.924410
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 6. Create Country Code Mapping

# %%
country_list = df_filter["Country Name"].unique()

# %%
code_map = {}
for i in range(len(country_list)):
    code_map[country_list[i]] = i

# %%
df_filter["country_code"] = df_filter["Country Name"].apply(lambda x: code_map[x])

# %%
df_filter
# Out:
#            Country Name Country Code      year  \
# 0             Australia          AUS -1.511794
# 1                Brazil          BRA -1.511794
# 2                Canada          CAN -1.511794
# 3           Switzerland          CHE -1.511794
# 4               Germany          DEU -1.511794
# ..                  ...          ...       ...
# 130              Poland          POL  1.474921
# 131  Russian Federation          RUS  1.474921
# 132        Saudi Arabia          SAU  1.474921
# 133             Turkiye          TUR  1.474921
# 134       United States          USA  1.474921
#
#      Rural population growth (annual %)  \
# 0                              1.186917
# 1                             -0.549959
# 2                              1.024320
# 3                              1.217270
# 4                              0.515165
# ..                                  ...
# 130                            0.347406
# 131                           -0.221817
# 132                            1.081275
# 133                           -0.134352
# 134                           -0.256489
#
#      General government final consumption expenditure (annual % growth)  \
# 0                                            -0.429109
# 1                                            -0.119310
# 2                                            -0.878494
# 3                                            -0.023838
# 4                                            -0.151886
# ..                                                 ...
# 130                                           1.522074
# 131                                           0.164466
# 132                                          -1.598615
# 133                                           0.672134
# 134                                           0.685293
#
#      Consumer price index (2010 = 100)  \
# 0                            -0.552582
# 1                            -0.022262
# 2                            -0.654727
# 3                            -0.933309
# 4                            -0.643825
# ..                                 ...
# 130                          -0.261270
# 131                           2.766513
# 132                          -0.066439
# 133                           5.205828
# 134                          -0.118946
#
#      Exports of goods and services (annual % growth)_x  \
# 0                                             0.587540
# 1                                            -0.500136
# 2                                            -0.305107
# 3                                             3.362653
# 4                                            -0.758610
# ..                                                 ...
# 130                                           0.597510
# 131                                          -0.843718
# 132                                          -2.636952
# 133                                           0.579116
# 134                                          -0.912948
#
#      Urban population growth (annual %)  GDP growth (annual %)  \
# 0                              1.085996               2.606198
# 1                              0.260984               3.004823
# 2                              0.134103               2.325814
# 3                              0.226917               1.792144
# 4                             -0.935218               0.437591
# ..                                  ...                    ...
# 130                           -1.384763               4.449988
# 131                           -1.102849               2.198076
# 132                            2.010008               0.832280
# 133                            1.395271               0.818526
# 134                           -0.393547               2.294439
#
#      Population growth (annual %)  ...  \
# 0                        1.635038  ...
# 1                        0.255734  ...
# 2                        0.560196  ...
# 3                        0.711079  ...
# 4                       -0.707325  ...
# ..                            ...  ...
# 130                     -1.188214  ...
# 131                     -1.228877  ...
# 132                      2.546327  ...
# 133                      1.163647  ...
# 134                     -0.412185  ...
#
#      Unemployment, total (% of total labor force) (national estimate)  \
# 0                                            -0.299153
# 1                                             0.040935
# 2                                             0.058325
# 3                                            -0.520402
# 4                                            -0.403498
# ..                                                 ...
# 130                                          -0.875465
# 131                                          -0.581029
# 132                                          -0.305674
# 133                                           1.649344
# 134                                          -0.780782
#
#      Inflation, consumer prices (annual %)  \
# 0                                -0.022781
# 1                                 1.204075
# 2                                -0.516735
# 3                                -0.894363
# 4                                -0.331639
# ..                                     ...
# 130                              -0.095459
# 131                               0.637463
# 132                              -1.507398
# 133                               4.136080
# 134                              -0.231159
#
#      Gross fixed capital formation (annual % growth)  \
# 0                                           0.138831
# 1                                           0.702851
# 2                                          -0.138377
# 3                                          -0.201905
# 4                                          -0.665766
# ..                                               ...
# 130                                         0.782558
# 131                                        -0.231013
# 132                                         0.510848
# 133                                        -2.813023
# 134                                         0.136616
#
#      Households and NPISHs Final consumption expenditure (annual % growth)  \
# 0                                            -0.138371
# 1                                             0.562389
# 2                                             0.181842
# 3                                             0.016326
# 4                                            -0.836209
# ..                                                 ...
# 130                                           0.530831
# 131                                           0.687472
# 132                                           1.916204
# 133                                          -0.323029
# 134                                          -0.099434
#
#      country  ADM0_ISO       sum      mean       std  country_code
# 0        AUS       CHN  0.501962 -0.727731 -0.477515             0
# 1        BRA       USA  2.354106 -0.296918 -0.236511             1
# 2        CAN       DEU -0.632732 -0.365696 -0.508137             2
# 3        CHE       JPN -0.578510  0.211631 -0.304815             3
# 4        DEU       IND -0.213108 -0.535505 -0.470838             4
# ..       ...       ...       ...       ...       ...           ...
# 130      POL       ESP -0.515721  0.165494 -0.194186            14
# 131      RUS       IDN -0.548933 -0.723306 -0.477408            15
# 132      SAU       NLD -0.680771  3.084582  3.526523            16
# 133      TUR       TUR -0.424090  0.060732 -0.310303            17
# 134      USA       SAU -0.101167 -0.005093  0.130760            18
#
# [135 rows x 23 columns]

# %%
len(data_v)
# Out:
# 18

# %% [markdown]
# ## 7. Prepare and Save Tensors

# %%
label_v = ["GDP growth (annual %)", "country_code", "year"]

# %%
data = torch.Tensor(df_filter[data_v].to_numpy())
data.size()
# Out:
# torch.Size([135, 18])

# %%
labels = torch.Tensor(df_filter[label_v].to_numpy())
labels.size()
# Out:
# torch.Size([135, 3])

# %%
labels[0]
# Out:
# tensor([ 2.6062,  0.0000, -1.5118])

# %%
torch.save(data, "../dataset/MLP_data_light_sms_y_13-19.pt")

# %%
torch.save(labels, "../dataset/MLP_label_light_sms_y_13-19.pt")

# %% [markdown]
# ✅ Complete! MLP yearly dataset with light intensity data has been generated and saved successfully.
