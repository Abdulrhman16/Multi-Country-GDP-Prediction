# %% [markdown]
# # Linear MLP Baseline (Quarter & Year)
#
# Convenience notebook to run the quarter (`linear_mlp_quarter.py`) and year (`linear_mlp_year.py`) linear baselines from `scripts/`.

# %% [markdown]
# ## Quarter Baseline
#
# Executes `scripts/linear_mlp_quarter.py`.

# %%
# !python ../scripts/linear_mlp_quarter.py

# %% [markdown]
# ## Year Baseline
#
# Executes `scripts/linear_mlp_year.py`.

# %%
# !python ../scripts/linear_mlp_year.py
