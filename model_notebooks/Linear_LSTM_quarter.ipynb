# %% [markdown]
# # Linear LSTM Baseline (Quarter)
#
# Runs the `scripts/linear_lstm_quarter.py` baseline, which trains the linear LSTM variant on the quarterly dataset.

# %%
# !python ../scripts/linear_lstm_quarter.py
