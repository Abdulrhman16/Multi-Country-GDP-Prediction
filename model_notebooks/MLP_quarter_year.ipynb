# %% [markdown]
# # MLP Quarter & Year Training
#
# This notebook provides convenient cells to run the quarter (`run_mlp_q.py`) and year (`run_mlp_y.py`) training pipelines that live in `scripts/`. Each cell simply invokes the corresponding script so the logic stays in sync with na

# %% [markdown]
# ## Quarter Dataset Training
#
# Runs `scripts/run_mlp_q.py` using the project root as the working directory.

# %%
# !python ../scripts/run_mlp_q.py

# %% [markdown]
# ## Year Dataset Training
#
# Runs `scripts/run_mlp_y.py` with the same environment.

# %%
# !python ../scripts/run_mlp_y.py
